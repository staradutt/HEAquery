# %%
# LLM HACKATHON 2025
# Data Cleaning Script for Alloy Datasets
# Author: Staradutt
import fitz  # PyMuPDF
import os
import hashlib

# Function to extract raw text from one PDF
def extract_text_from_pdf(pdf_path):
    try:
        doc = fitz.open(pdf_path)
    except Exception as e:
        print(f"Skipping {pdf_path}: {e}")
        return None  # Return None if opening fails

    text = ""
    for page in doc:
        text += page.get_text("text") + "\n"
    return text

# Deduplication helper (hash content to detect duplicates)
def get_text_hash(text):
    return hashlib.md5(text.encode("utf-8")).hexdigest()

# Main loop: load all PDFs into dict
folder = "pdfs/all"  # folder containing your 3000+ open access PDFs
corpus = {}
seen_hashes = set()

for file in os.listdir(folder):
    if file.lower().endswith(".pdf"):
        pdf_path = os.path.join(folder, file)
        text = extract_text_from_pdf(pdf_path)
        if text is None:
            continue  # Skip this file due to error
        text_hash = get_text_hash(text)
        if text_hash not in seen_hashes:  # skip duplicates
            corpus[file] = text
            seen_hashes.add(text_hash)

print(f"Successfully processed {len(corpus)} unique PDFs.")
# Out:
# Skipping pdfs/all\054116_1_5.0137117.pdf: Failed to open file 'pdfs/all\\054116_1_5.0137117.pdf'.
# MuPDF error: format error: cannot find page 99 in page tree
#
# MuPDF error: format error: cannot find page 104 in page tree
#
# MuPDF error: format error: cannot find page 108 in page tree
#
# MuPDF error: format error: cannot find page 110 in page tree
#
# MuPDF error: format error: cannot find page 112 in page tree
#
# MuPDF error: format error: cannot find page 112 in page tree
#
# MuPDF error: format error: cannot find page 112 in page tree
#
# MuPDF error: format error: cannot find page 113 in page tree
#
# MuPDF error: format error: cannot find page 113 in page tree
#
# MuPDF error: format error: cannot find page 114 in page tree
#
# MuPDF error: format error: cannot find page 117 in page tree
#
# MuPDF error: format error: cannot find page 122 in page tree
#
# MuPDF error: format error: cannot find page 124 in page tree
#
# MuPDF error: format error: cannot find page 126 in page tree
#
# MuPDF error: format error: cannot find page 126 in page tree
#
# MuPDF error: format error: cannot find page 126 in page tree
#
# MuPDF error: format error: cannot find page 126 in page tree
#
# MuPDF error: format error: cannot find page 126 in page tree
#
# MuPDF error: format error: cannot find page 128 in page tree
#
# MuPDF error: format error: cannot find page 131 in page tree
#
# MuPDF error: format error: cannot find page 137 in page tree
#
# MuPDF error: format error: cannot find page 140 in page tree
#
# MuPDF error: format error: cannot find page 142 in page tree
#
# MuPDF error: format error: cannot find page 142 in page tree
#
# MuPDF error: format error: cannot find page 142 in page tree
#
# MuPDF error: format error: cannot find page 143 in page tree
#
# MuPDF error: format error: cannot find page 148 in page tree
#
# MuPDF error: format error: cannot find page 154 in page tree
#
# MuPDF error: format error: cannot find page 156 in page tree
#
# MuPDF error: format error: cannot find page 160 in page tree
#
# MuPDF error: format error: cannot find page 99 in page tree
#
# MuPDF error: format error: cannot find page 99 in page tree
#
# MuPDF error: format error: cannot find page 100 in page tree
#
# MuPDF error: format error: cannot find page 100 in page tree
#
# MuPDF error: format error: cannot find page 101 in page tree
#
# MuPDF error: format error: cannot find page 101 in page tree
#
# MuPDF error: format error: cannot find page 102 in page tree
#
# MuPDF error: format error: cannot find page 102 in page tree
#
# MuPDF error: format error: cannot find page 103 in page tree
#
# MuPDF error: format error: cannot find page 103 in page tree
#
# MuPDF error: format error: cannot find page 104 in page tree
#
# MuPDF error: format error: cannot find page 104 in page tree
#
# MuPDF error: format error: cannot find page 104 in page tree
#
# MuPDF error: format error: cannot find page 106 in page tree
#
# MuPDF error: format error: cannot find page 106 in page tree
#
# MuPDF error: format error: cannot find page 106 in page tree
#
# MuPDF error: format error: cannot find page 107 in page tree
#
# MuPDF error: format error: cannot find page 107 in page tree
#
# MuPDF error: format error: cannot find page 108 in page tree
#
# MuPDF error: format error: cannot find page 108 in page tree
#
# MuPDF error: format error: cannot find page 108 in page tree
#
# MuPDF error: format error: cannot find page 109 in page tree
#
# MuPDF error: format error: cannot find page 109 in page tree
#
# MuPDF error: format error: cannot find page 110 in page tree
#
# MuPDF error: format error: cannot find page 110 in page tree
#
# MuPDF error: format error: cannot find page 113 in page tree
#
# MuPDF error: format error: cannot find page 113 in page tree
#
# MuPDF error: format error: cannot find page 114 in page tree
#
# MuPDF error: format error: cannot find page 114 in page tree
#
# MuPDF error: format error: cannot find page 115 in page tree
#
# MuPDF error: format error: cannot find page 115 in page tree
#
# MuPDF error: format error: cannot find page 115 in page tree
#
# MuPDF error: format error: cannot find page 117 in page tree
#
# MuPDF error: format error: cannot find page 117 in page tree
#
# MuPDF error: format error: cannot find page 117 in page tree
#
# MuPDF error: format error: cannot find page 119 in page tree
#
# MuPDF error: format error: cannot find page 119 in page tree
#
# MuPDF error: format error: cannot find page 121 in page tree
#
# MuPDF error: format error: cannot find page 121 in page tree
#
# MuPDF error: format error: cannot find page 121 in page tree
#
# MuPDF error: format error: cannot find page 121 in page tree
#
# MuPDF error: format error: cannot find page 121 in page tree
#
# MuPDF error: format error: cannot find page 122 in page tree
#
# MuPDF error: format error: cannot find page 122 in page tree
#
# MuPDF error: format error: cannot find page 122 in page tree
#
# MuPDF error: format error: cannot find page 123 in page tree
#
# MuPDF error: format error: cannot find page 123 in page tree
#
# MuPDF error: format error: cannot find page 123 in page tree
#
# MuPDF error: format error: cannot find page 127 in page tree
#
# MuPDF error: format error: cannot find page 127 in page tree
#
# MuPDF error: format error: cannot find page 128 in page tree
#
# MuPDF error: format error: cannot find page 128 in page tree
#
# MuPDF error: format error: cannot find page 128 in page tree
#
# MuPDF error: format error: cannot find page 130 in page tree
#
# MuPDF error: format error: cannot find page 130 in page tree
#
# MuPDF error: format error: cannot find page 131 in page tree
#
# MuPDF error: format error: cannot find page 131 in page tree
#
# MuPDF error: format error: cannot find page 134 in page tree
#
# MuPDF error: format error: cannot find page 134 in page tree
#
# MuPDF error: format error: cannot find page 134 in page tree
#
# MuPDF error: format error: cannot find page 135 in page tree
#
# MuPDF error: format error: cannot find page 135 in page tree
#
# MuPDF error: format error: cannot find page 137 in page tree
#
# MuPDF error: format error: cannot find page 137 in page tree
#
# MuPDF error: format error: cannot find page 139 in page tree
#
# MuPDF error: format error: cannot find page 139 in page tree
#
# MuPDF error: format error: cannot find page 139 in page tree
#
# MuPDF error: format error: cannot find page 139 in page tree
#
# MuPDF error: format error: cannot find page 140 in page tree
#
# MuPDF error: format error: cannot find page 140 in page tree
#
# MuPDF error: format error: cannot find page 144 in page tree
#
# MuPDF error: format error: cannot find page 144 in page tree
#
# MuPDF error: format error: cannot find page 147 in page tree
#
# MuPDF error: format error: cannot find page 147 in page tree
#
# MuPDF error: format error: cannot find page 148 in page tree
#
# MuPDF error: format error: cannot find page 148 in page tree
#
# MuPDF error: format error: cannot find page 149 in page tree
#
# MuPDF error: format error: cannot find page 149 in page tree
#
# MuPDF error: format error: cannot find page 149 in page tree
#
# MuPDF error: format error: cannot find page 149 in page tree
#
# MuPDF error: format error: cannot find page 150 in page tree
#
# MuPDF error: format error: cannot find page 150 in page tree
#
# MuPDF error: format error: cannot find page 151 in page tree
#
# MuPDF error: format error: cannot find page 151 in page tree
#
# MuPDF error: format error: cannot find page 151 in page tree
#
# MuPDF error: format error: cannot find page 152 in page tree
#
# MuPDF error: format error: cannot find page 152 in page tree
#
# MuPDF error: format error: cannot find page 152 in page tree
#
# MuPDF error: format error: cannot find page 153 in page tree
#
# MuPDF error: format error: cannot find page 153 in page tree
#
# MuPDF error: format error: cannot find page 153 in page tree
#
# MuPDF error: format error: cannot find page 153 in page tree
#
# MuPDF error: format error: cannot find page 154 in page tree
#
# MuPDF error: format error: cannot find page 154 in page tree
#
# MuPDF error: format error: cannot find page 154 in page tree
#
# MuPDF error: format error: cannot find page 112 in page tree
#
# MuPDF error: format error: cannot find page 112 in page tree
#
# MuPDF error: format error: cannot find page 112 in page tree
#
# MuPDF error: format error: cannot find page 112 in page tree
#
# MuPDF error: format error: cannot find page 116 in page tree
#
# MuPDF error: format error: cannot find page 116 in page tree
#
# MuPDF error: format error: cannot find page 116 in page tree
#
# MuPDF error: format error: cannot find page 126 in page tree
#
# MuPDF error: format error: cannot find page 126 in page tree
#
# MuPDF error: format error: cannot find page 126 in page tree
#
# MuPDF error: format error: cannot find page 126 in page tree
#
# MuPDF error: format error: cannot find page 130 in page tree
#
# MuPDF error: format error: cannot find page 130 in page tree
#
# MuPDF error: format error: cannot find page 130 in page tree
#
# MuPDF error: format error: cannot find page 130 in page tree
#
# MuPDF error: format error: cannot find page 130 in page tree
#
# MuPDF error: format error: cannot find page 130 in page tree
#
# MuPDF error: format error: cannot find page 143 in page tree
#
# MuPDF error: format error: cannot find page 143 in page tree
#
# MuPDF error: format error: cannot find page 143 in page tree
#
# MuPDF error: format error: cannot find page 143 in page tree
#
# MuPDF error: format error: cannot find page 143 in page tree
#
# MuPDF error: format error: cannot find page 144 in page tree
#
# MuPDF error: format error: cannot find page 144 in page tree
#
# MuPDF error: format error: cannot find page 144 in page tree
#
# MuPDF error: format error: cannot find page 147 in page tree
#
# MuPDF error: format error: cannot find page 147 in page tree
#
# MuPDF error: format error: cannot find page 99 in page tree
#
# MuPDF error: format error: cannot find page 99 in page tree
#
# MuPDF error: format error: cannot find page 99 in page tree
#
# MuPDF error: format error: cannot find page 99 in page tree
#
# MuPDF error: format error: cannot find page 100 in page tree
#
# MuPDF error: format error: cannot find page 100 in page tree
#
# MuPDF error: format error: cannot find page 100 in page tree
#
# MuPDF error: format error: cannot find page 100 in page tree
#
# MuPDF error: format error: cannot find page 101 in page tree
#
# MuPDF error: format error: cannot find page 101 in page tree
#
# MuPDF error: format error: cannot find page 102 in page tree
#
# MuPDF error: format error: cannot find page 103 in page tree
#
# MuPDF error: format error: cannot find page 103 in page tree
#
# MuPDF error: format error: cannot find page 103 in page tree
#
# MuPDF error: format error: cannot find page 104 in page tree
#
# MuPDF error: format error: cannot find page 104 in page tree
#
# MuPDF error: format error: cannot find page 104 in page tree
#
# MuPDF error: format error: cannot find page 106 in page tree
#
# MuPDF error: format error: cannot find page 103 in page tree
#
# MuPDF error: format error: cannot find page 106 in page tree
#
# MuPDF error: format error: cannot find page 106 in page tree
#
# MuPDF error: format error: cannot find page 106 in page tree
#
# MuPDF error: format error: cannot find page 106 in page tree
#
# MuPDF error: format error: cannot find page 107 in page tree
#
# MuPDF error: format error: cannot find page 108 in page tree
#
# MuPDF error: format error: cannot find page 107 in page tree
#
# MuPDF error: format error: cannot find page 107 in page tree
#
# MuPDF error: format error: cannot find page 108 in page tree
#
# MuPDF error: format error: cannot find page 108 in page tree
#
# MuPDF error: format error: cannot find page 109 in page tree
#
# MuPDF error: format error: cannot find page 109 in page tree
#
# MuPDF error: format error: cannot find page 109 in page tree
#
# MuPDF error: format error: cannot find page 110 in page tree
#
# MuPDF error: format error: cannot find page 110 in page tree
#
# MuPDF error: format error: cannot find page 110 in page tree
#
# MuPDF error: format error: cannot find page 110 in page tree
#
# MuPDF error: format error: cannot find page 126 in page tree
#
# MuPDF error: format error: cannot find page 127 in page tree
#
# MuPDF error: format error: cannot find page 126 in page tree
#
# MuPDF error: format error: cannot find page 128 in page tree
#
# MuPDF error: format error: cannot find page 126 in page tree
#
# MuPDF error: format error: cannot find page 130 in page tree
#
# MuPDF error: format error: cannot find page 130 in page tree
#
# MuPDF error: format error: cannot find page 130 in page tree
#
# MuPDF error: format error: cannot find page 130 in page tree
#
# MuPDF error: format error: cannot find page 130 in page tree
#
# MuPDF error: format error: cannot find page 130 in page tree
#
# MuPDF error: format error: cannot find page 130 in page tree
#
# MuPDF error: format error: cannot find page 131 in page tree
#
# MuPDF error: format error: cannot find page 126 in page tree
#
# MuPDF error: format error: cannot find page 134 in page tree
#
# MuPDF error: format error: cannot find page 134 in page tree
#
# MuPDF error: format error: cannot find page 134 in page tree
#
# MuPDF error: format error: cannot find page 134 in page tree
#
# MuPDF error: format error: cannot find page 135 in page tree
#
# MuPDF error: format error: cannot find page 135 in page tree
#
# MuPDF error: format error: cannot find page 135 in page tree
#
# MuPDF error: format error: cannot find page 126 in page tree
#
# MuPDF error: format error: cannot find page 130 in page tree
#
# MuPDF error: format error: cannot find page 137 in page tree
#
# MuPDF error: format error: cannot find page 137 in page tree
#
# MuPDF error: format error: cannot find page 137 in page tree
#
# MuPDF error: format error: cannot find page 137 in page tree
#
# MuPDF error: format error: cannot find page 137 in page tree
#
# MuPDF error: format error: cannot find page 137 in page tree
#
# MuPDF error: format error: cannot find page 126 in page tree
#
# MuPDF error: format error: cannot find page 130 in page tree
#
# MuPDF error: format error: cannot find page 139 in page tree
#
# MuPDF error: format error: cannot find page 139 in page tree
#
# MuPDF error: format error: cannot find page 139 in page tree
#
# MuPDF error: format error: cannot find page 139 in page tree
#
# MuPDF error: format error: cannot find page 139 in page tree
#
# MuPDF error: format error: cannot find page 139 in page tree
#
# MuPDF error: format error: cannot find page 140 in page tree
#
# MuPDF error: format error: cannot find page 140 in page tree
#
# MuPDF error: format error: cannot find page 143 in page tree
#
# MuPDF error: format error: cannot find page 143 in page tree
#
# MuPDF error: format error: cannot find page 144 in page tree
#
# MuPDF error: format error: cannot find page 144 in page tree
#
# MuPDF error: format error: cannot find page 144 in page tree
#
# MuPDF error: format error: cannot find page 144 in page tree
#
# MuPDF error: format error: cannot find page 147 in page tree
#
# MuPDF error: format error: cannot find page 147 in page tree
#
# MuPDF error: format error: cannot find page 147 in page tree
#
# MuPDF error: format error: cannot find page 147 in page tree
#
# MuPDF error: format error: cannot find page 147 in page tree
#
# MuPDF error: format error: cannot find page 147 in page tree
#
# MuPDF error: format error: cannot find page 147 in page tree
#
# MuPDF error: format error: cannot find page 147 in page tree
#
# MuPDF error: format error: cannot find page 148 in page tree
#
# MuPDF error: format error: cannot find page 144 in page tree
#
# MuPDF error: format error: cannot find page 144 in page tree
#
# MuPDF error: format error: cannot find page 147 in page tree
#
# MuPDF error: format error: cannot find page 149 in page tree
#
# MuPDF error: format error: cannot find page 149 in page tree
#
# MuPDF error: format error: cannot find page 150 in page tree
#
# MuPDF error: format error: cannot find page 150 in page tree
#
# MuPDF error: format error: cannot find page 144 in page tree
#
# MuPDF error: format error: cannot find page 144 in page tree
#
# MuPDF error: format error: cannot find page 150 in page tree
#
# MuPDF error: format error: cannot find page 151 in page tree
#
# MuPDF error: format error: cannot find page 151 in page tree
#
# MuPDF error: format error: cannot find page 151 in page tree
#
# MuPDF error: format error: cannot find page 152 in page tree
#
# MuPDF error: format error: cannot find page 151 in page tree
#
# MuPDF error: format error: cannot find page 152 in page tree
#
# MuPDF error: format error: cannot find page 152 in page tree
#
# MuPDF error: format error: cannot find page 153 in page tree
#
# MuPDF error: format error: cannot find page 153 in page tree
#
# MuPDF error: format error: cannot find page 154 in page tree
#
# MuPDF error: format error: cannot find page 154 in page tree
#
# MuPDF error: syntax error: could not parse color space (230 0 R)
#
# MuPDF error: syntax error: could not parse color space (391 0 R)
#
# MuPDF error: syntax error: could not parse color space (387 0 R)
#
# MuPDF error: syntax error: could not parse color space (225 0 R)
#
# MuPDF error: syntax error: could not parse color space (424 0 R)
#
# MuPDF error: syntax error: could not parse color space (525 0 R)
#
# MuPDF error: syntax error: could not parse color space (698 0 R)
#
# MuPDF error: syntax error: could not parse color space (212 0 R)
#
# MuPDF error: syntax error: could not parse color space (901 0 R)
#
# Successfully processed 3661 unique PDFs.

# %%
import re

def extract_sections(text):
    sections = {}
    patterns = {
        "abstract": r"(?i)(abstract)(.*?)(?=\n\s*(introduction|1\.|I\.))",
        "introduction": r"(?i)(introduction)(.*?)(?=\n\s*(methods|experimental|2\.|II\.))",
        "methods": r"(?i)(methods|experimental)(.*?)(?=\n\s*(results|discussion|3\.|III\.))",
        "conclusion": r"(?i)(conclusion|summary)(.*?)(?=\n\s*references|\Z)",
    }
    for name, pattern in patterns.items():
        match = re.search(pattern, text, re.S)
        if match:
            sections[name] = match.group(0)
    return sections

# Example: extract sections for one PDF
sections = extract_sections(list(corpus.values())[0])
print(sections.keys())
# Out:
# dict_keys(['abstract', 'introduction', 'methods', 'conclusion'])

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,   # adjust if needed
    chunk_overlap=50,
    separators=["\n\n", "\n", ".", " "]
)

chunks = []
for file, text in corpus.items():
    sections = extract_sections(text)
    for sec_name, sec_text in sections.items():
        # include filename + section for traceability
        split = splitter.split_text(sec_text)
        chunks.extend([f"{file} - {sec_name}: {chunk}" for chunk in split])

print("Total chunks:", len(chunks))
# Out:
# Total chunks: 253733

# %%
import pickle

# Save all chunks
with open("chunks_new.pkl", "wb") as f:
    pickle.dump(chunks, f)
